# %%
import sys
print(sys.executable)
# Out:
# C:\Users\kasum\Desktop\100 days of code\DAY 71 Data Science\.venv\Scripts\python.exe

# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 3.0.5

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.5.2

# %%
import matplotlib
import seaborn

print("Everything is working")
# Out:
# Everything is working

# %%
df = pd.read_csv("salaries_by_college_major.csv")

# %%
df.head()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0              Accounting                   46000                     77000
# 1   Aerospace Engineering                   64000                    100000
# 2  Agricultural Economics                   43000                     78000
# 3            Architecture                   50000                     85000
# 4             Art History                   42000                     76000
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                              45000                             140000
# 1                              65000                             160000
# 2                              48000                             135000
# 3                              52000                             150000
# 4                              45000                             125000

# %%
df
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0               Accounting                   46000                     77000
# 1    Aerospace Engineering                   64000                    100000
# 2   Agricultural Economics                   43000                     78000
# 3             Architecture                   50000                     85000
# 4              Art History                   42000                     76000
# 5                  Biology                   40000                     70000
# 6      Business Management                   45000                     85000
# 7     Chemical Engineering                   65000                    110000
# 8        Civil Engineering                   56000                     88000
# 9     Computer Engineering                   61000                    105000
# 10        Computer Science                   62000                    105000
# ...

# %%
df.shape
# Out:
# (28, 5)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary'],
#       dtype='str')

# %%
df["Undergraduate Major"].loc[10]
# Out:
# 'Computer Science'

# %%
df.loc[10]
# Out:
# Undergraduate Major                  Computer Science
# Starting Median Salary                          62000
# Mid-Career Median Salary                       105000
# Mid-Career 10th Percentile Salary               68000
# Mid-Career 90th Percentile Salary              180000
# Name: 10, dtype: object

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary'],
#       dtype='str')

# %%
df.loc[df['Mid-Career Median Salary'].idxmax()
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                              65000
# Mid-Career Median Salary                           110000
# Mid-Career 10th Percentile Salary                   70000
# Mid-Career 90th Percentile Salary                  170000
# Name: 7, dtype: object

# %%
df.loc[df['Mid-Career Median Salary'].idxmax(),'Undergraduate Major']
# Out:
# 'Chemical Engineering'

# %%
df.loc[df['Mid-Career Median Salary'].idxmax(),'Starting Median Salary']
# Out:
# np.int64(65000)

# %%
df.loc[df['Starting Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Theology
# Starting Median Salary                  35000
# Mid-Career Median Salary                65000
# Mid-Career 10th Percentile Salary       35000
# Mid-Career 90th Percentile Salary      105000
# Name: 27, dtype: object

# %%
# highest potential

highest_potential = df.sort_values('Mid-Career 90th Percentile Salary' ,ascending=False)
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 10        Computer Science                   62000                    105000
# 9     Computer Engineering                   61000                    105000
# 21                Pharmacy                   62000                    105000
# 7     Chemical Engineering                   65000                    110000
# 12  Electrical Engineering                   60000                    102000
# 26              Statistics                   57000                     98000
# 14                 Finance                   50000                     95000
# 8        Civil Engineering                   56000                     88000
# 1    Aerospace Engineering                   64000                    100000
# 19  Mechanical Engineering                   58000                     95000
# 22                 Physics                   55000                     93000
# ...
